# %% [markdown]
# <a href="https://colab.research.google.com/github/drAshcroft/MAT421_Brian/blob/main/Module_G_Numerical_Integration_21_1%2C21_2%2C21_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load needed libraries

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
# !pip install sympy
import sympy
import numpy as np
from sympy.plotting import plot 
from sympy import *
x = sympy.Symbol('x')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Exact integrals can be found for a number of situations, if possible this is the best for generality, but is not normally possible for real scientific and engineering projects

# %%
f=sin(x)

F=integrate(f, x) # integrate function
print("The integral of ")
display(f)
print("is")
display(F)

p1 = plot(f, show=False)
p2 = plot(F, show=False)
p1.append(p2[0])
p1.show()

f=sin(x)*x 
F=integrate(f, x)
display(F)
# Out:
# The integral of
# sin(x)
# is
# -cos(x)
# -x*cos(x) + sin(x)

# %% [markdown]
# Numerical integration is the process of finding the area under a curve from imperfect data.  The simplest method is to just take each value and multiply it by the sampling rate.

# %%
dx=.3
x=np.linspace(0,6, int(6/dx))

f=np.sin(x)*x

print('Our starting function')
plt.plot(x,f, label='sin(x)*x')

sum=0
F=np.zeros_like(f)
for i in range(len(f)):
  sum+=f[i]*dx
  F[i]=sum

print('Simple numerically integrated function')
plt.plot(x,F, label='num integral(sin(x)*x)')  

realAnswer =  np.sin(x)-x*np.cos(x)
plt.plot(x,realAnswer, label='real integral(sin(x)*x)')  
plt.legend()

print('Error = %.2f' % np.mean( (F-realAnswer)**2)**.5)
# Out:
# Our starting function
# Simple numerically integrated function
# Error = 0.34

# %% [markdown]
# Trapezoid rule provides a better approximation of the area under each subdivision by simplifying to step by a trapezoid.  This linear transform means that more accuracy is found without computing smaller segments

# %%
 

dx=.3
x=np.linspace(0,6, int(6/dx))

f=np.sin(x)*x

print('Our starting function')
plt.plot(x,f, label='sin(x)*x')

sum=0
F=np.zeros(len(f))
for i in range(len(f)-1):
  sum+=(f[i]+f[1+i])/2*dx
  F[i+1]=sum

print('Trapezoidal numerically integrated function')
plt.plot(x,F, label='num integral(sin(x)*x)')  

realAnswer =  np.sin(x)-x*np.cos(x)
plt.plot(x,realAnswer, label='real integral(sin(x)*x)')  
plt.legend()

print('Error = %.2f' % np.mean( (F[1:]-realAnswer[1:])**2)**.5)
# Out:
# Our starting function
# Trapezoidal numerically integrated function
# Error = 0.15

# %%
F
# Out:
# -5.99481556675597
